# %% [markdown]
# # 2D Quadrocopter in Vertical Labyrinth (2DQVL)

# %% [markdown]
# ## System description
# $$u_1 \in [0.,1.]$$
# $$u_2 \in [0.,1.]$$
# $$\varphi \in [-\pi/2,\pi/2]$$
# $$g = 9.81$$
# $$I = \frac{1}{12}m(l_x^2 + l_y^2)$$
# $$R = \frac{0.5l_x}{I}$$
#
# $u_1,u_2$ - controler parameters, power of left and right engines
#
# $\varphi$ - angle of quadrocopter
#
# $I$ - moment of inertia

# %%
s.visualize_state(state,action,scale=2, additional_windows=False)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x400>

# %% [markdown]
# # System dynamics
#
# $$
# \begin{cases}
# \dot{c_x} = v_x\\
# \dot{c_y} = v_y\\
# \dot{v_x} = -g * (u_1 + u_2)*\sin(\varphi)\\
# \dot{v_y} = g * (u_1 + u_2)\cos(\varphi) - g\\
# \dot{\varphi} = \theta\\
# \dot{\theta} = R(u_2 - u_1)\\
# \end{cases}
# $$

# %% [markdown]
# # Initial conditions
#
# $$
# \begin{cases}
# c_x = l_x / 2\\
# c_y = l_y / 2\\
# v_x = 0\\
# v_y = 0\\
# \varphi = 0\\
# \theta = 0\\
# \end{cases}
# $$
